# %%
print("Halloo Semua, Environment Machine Learning Berhasil Dibuat")
# Out:
# Halloo Semua, Environment Machine Learning Berhasil Dibuat

# %%
import numpy
import matplotlib
import cv2

print("Semua Library Berhasil Diimport")
# Out:
# Semua Library Berhasil Diimport
